# %% [markdown]
# ## A comparison between the different regressors

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.linear_models.linear_regression import LinearRegression
from allison.linear_models.polinomic_regression import PolinomicRegression
from allison.linear_models.functional_regression import FunctionalRegression
from allison.utils.functions.loss import mean_squared_error
from allison.utils.metrics import r2_score

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,100)
y=x+ 2*np.sin(x) +0.5*np.random.randn(100)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression(loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 9.257% 	 r2_score: 52.68%
#
# Iter:	10	==================================================>	 mean_squared_error: 2.857% 	 r2_score: 90.02%
#
# Iter:	15	==================================================>	 mean_squared_error: 2.258% 	 r2_score: 92.93%
#
# Iter:	20	==================================================>	 mean_squared_error: 2.218% 	 r2_score: 93.28%
#
# Iter:	25	==================================================>	 mean_squared_error: 2.222% 	 r2_score: 93.35%
#
# Iter:	30	==================================================>	 mean_squared_error: 2.224% 	 r2_score: 93.36%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression()
model.optimizers(base_functions=["x","sinx"],
                loss_function=mean_squared_error,
                lr=0.001,
                metrics=r2_score)
                
history=model.train(n_iters=30,
                    features=x,
                    labels=y,
                    callbacks_period=5)
# Out:
# Iter:	5	==================================================>	 r2_score:	0.94%
#
#
# Iter:	10	==================================================>	 r2_score:	0.94%
#
#
# Iter:	15	==================================================>	 r2_score:	0.94%
#
#
# Iter:	20	==================================================>	 r2_score:	0.94%
#
#
# Iter:	25	==================================================>	 r2_score:	0.94%
#
#
# Iter:	30	==================================================>	 r2_score:	0.94%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression(n_grade=1,
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)
history=model.train(n_iters=100,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 1403.298% 	 r2_score: -1249381.62%
#
# Iter:	10	==================================================>	 mean_squared_error: 1025.809% 	 r2_score: -9170.26%
#
# Iter:	15	==================================================>	 mean_squared_error: 787.351% 	 r2_score: -2395.60%
#
# Iter:	20	==================================================>	 mean_squared_error: 634.419% 	 r2_score: -1067.81%
#
# Iter:	25	==================================================>	 mean_squared_error: 534.705% 	 r2_score: -604.28%
#
# Iter:	30	==================================================>	 mean_squared_error: 468.548% 	 r2_score: -393.75%
#
# Iter:	35	==================================================>	 mean_squared_error: 423.867% 	 r2_score: -282.37%
#
# Iter:	40	==================================================>	 mean_squared_error: 393.158% 	 r2_score: -217.30%
#
# Iter:	45	==================================================>	 mean_squared_error: 371.698% 	 r2_score: -176.57%
#
# Iter:	50	==================================================>	 mean_squared_error: 356.471% 	 r2_score: -149.78%
#
# Iter:	55	==================================================>	 mean_squared_error: 345.518% 	 r2_score: -131.50%
#
# Iter:	60	==================================================>	 mean_squared_error: 337.545% 	 r2_score: -118.68%
#
# Iter:	65	==================================================>	 mean_squared_error: 331.683% 	 r2_score: -109.50%
#
# Iter:	70	==================================================>	 mean_squared_error: 327.336% 	 r2_score: -102.82%
#
# Iter:	75	==================================================>	 mean_squared_error: 324.092% 	 r2_score: -97.90%
#
# Iter:	80	==================================================>	 mean_squared_error: 321.656% 	 r2_score: -94.25%
#
# Iter:	85	==================================================>	 mean_squared_error: 319.820% 	 r2_score: -91.52%
#
# Iter:	90	==================================================>	 mean_squared_error: 318.431% 	 r2_score: -89.46%
#
# Iter:	95	==================================================>	 mean_squared_error: 317.378% 	 r2_score: -87.90%
#
# Iter:	100	==================================================>	 mean_squared_error: 316.577% 	 r2_score: -86.73%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression(n_grade=2,
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score)

history=model.train(n_iters=200,
                    features=x,
                    labels=y,
                    callbacks_period=20,history_train=True)
# Out:
# Iter:	20	==================================================>	 mean_squared_error: 67.855% 	 r2_score: 86.00%
#
# Iter:	40	==================================================>	 mean_squared_error: 64.543% 	 r2_score: 86.93%
#
# Iter:	60	==================================================>	 mean_squared_error: 64.525% 	 r2_score: 86.94%
#
# Iter:	80	==================================================>	 mean_squared_error: 64.525% 	 r2_score: 86.94%
#
# Iter:	100	==================================================>	 mean_squared_error: 64.525% 	 r2_score: 86.94%
#
# Iter:	120	==================================================>	 mean_squared_error: 64.525% 	 r2_score: 86.94%
#
# Iter:	140	==================================================>	 mean_squared_error: 64.525% 	 r2_score: 86.94%
#
# Iter:	160	==================================================>	 mean_squared_error: 64.525% 	 r2_score: 86.94%
#
# Iter:	180	==================================================>	 mean_squared_error: 64.525% 	 r2_score: 86.94%
#
# Iter:	200	==================================================>	 mean_squared_error: 64.525% 	 r2_score: 86.94%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
