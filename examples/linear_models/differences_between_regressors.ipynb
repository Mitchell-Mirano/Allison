# %% [markdown]
# ## A comparison between the different regressors

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.linear_models.linear_regression import LinearRegression
from allison.linear_models.polinomic_regression import PolinomicRegression
from allison.linear_models.functional_regression import FunctionalRegression
from allison.utils.functions.loss import mean_square_error
from allison.utils.metrics import r2_score, recall

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,100)
y=x+ 2*np.sin(x) +0.5*np.random.randn(100)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression()

model.optimizers(loss_function=mean_square_error,
                lr=0.001,
                metrics=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5)
# Out:
# Iter:	5	==================================================>	 r2_score:	71.26%
#
#
# Iter:	10	==================================================>	 r2_score:	91.01%
#
#
# Iter:	15	==================================================>	 r2_score:	93.22%
#
#
# Iter:	20	==================================================>	 r2_score:	93.50%
#
#
# Iter:	25	==================================================>	 r2_score:	93.54%
#
#
# Iter:	30	==================================================>	 r2_score:	93.55%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression()
model.optimizers(base_functions=["x","sinx"],
                loss_function=mean_square_error,
                lr=0.001,
                metrics=r2_score)
                
history=model.train(n_iters=30,
                    features=x,
                    labels=y,
                    callbacks_period=5)
# Out:
# Iter:	5	==================================================>	 r2_score:	60.49%
#
#
# Iter:	10	==================================================>	 r2_score:	93.81%
#
#
# Iter:	15	==================================================>	 r2_score:	97.02%
#
#
# Iter:	20	==================================================>	 r2_score:	97.26%
#
#
# Iter:	25	==================================================>	 r2_score:	97.26%
#
#
# Iter:	30	==================================================>	 r2_score:	97.25%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression()
model.optimizers(n_grade=1,
                loss_function=mean_square_error,
                lr=0.01,
                metrics=r2_score)
history=model.train(n_iters=30,
                    features=x,
                    labels=y,
                    callbacks_period=5)
# Out:
# Iter:	5	==================================================>	 r2_score:	62.59%
#
#
# Iter:	10	==================================================>	 r2_score:	65.82%
#
#
# Iter:	15	==================================================>	 r2_score:	65.89%
#
#
# Iter:	20	==================================================>	 r2_score:	65.89%
#
#
# Iter:	25	==================================================>	 r2_score:	65.89%
#
#
# Iter:	30	==================================================>	 r2_score:	65.89%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression()
model.optimizers(n_grade=2,
                loss_function=mean_square_error,
                lr=0.0001,
                metrics=r2_score)
history=model.train(n_iters=100,
                    features=x,
                    labels=y,
                    callbacks_period=20)
# Out:
# Iter:	20	==================================================>	 r2_score:	91.79%
#
#
# Iter:	40	==================================================>	 r2_score:	92.12%
#
#
# Iter:	60	==================================================>	 r2_score:	92.12%
#
#
# Iter:	80	==================================================>	 r2_score:	92.12%
#
#
# Iter:	100	==================================================>	 r2_score:	92.12%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
