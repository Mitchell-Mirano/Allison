# %%
import os

# %%
os.chdir('../../')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(2,20,100)
y=2*x + 1 + 2*np.sin(x) + np.random.randn(100)

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y,s=50)

# %%
from linear_models import LinearRegression
from utils.functions.loss import mean_square_error
from utils.metrics import r2_score

# %%
model=LinearRegression()

model.optimizers(loss_function=mean_square_error,
                 lr=0.001, 
                 metrics=r2_score)

# %%
hist_train=model.train(n_iters=10,
            features=x, 
            labels=y, 
            callbacks_period=2)
# Out:
# Iter:	2	==================================================>	 r2_score:	-161.85%
#
#
# Iter:	4	==================================================>	 r2_score:	13.12%
#
#
# Iter:	6	==================================================>	 r2_score:	69.92%
#
#
# Iter:	8	==================================================>	 r2_score:	88.27%
#
#
# Iter:	10	==================================================>	 r2_score:	94.14%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y,s=50)
plt.plot(x,model.predict(x), lw=3, c='red')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-aa7bd19c8f69> in <module>
#       1 plt.figure(figsize=(12,8))
#       2 plt.scatter(x,y,s=50)
# ----> 3 plt.plot(x,model.predict(x), lw=3, c='red')
#
# ~/Escritorio/Allison/env/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/Escritorio/Allison/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
