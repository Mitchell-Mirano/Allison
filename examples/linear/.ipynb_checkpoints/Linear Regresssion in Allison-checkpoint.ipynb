# %%
import os

# %%
os.chdir('../../')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from linear_models import LinearRegression
from utils.functions.loss import mean_square_error, binary_cross_entropy
from utils.metrics import r2_score, accuracy

# %%
x=np.linspace(2,20,100)
y=2*x + 1 + 2*np.sin(x) + np.random.randn(100)

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y,s=50)

# %%
model=LinearRegression()

model.optimizers(loss_function=mean_square_error,
                 lr=0.001, 
                 metrics=r2_score)

# %%
hist_train=model.train(n_iters=10,
            features=x, 
            labels=y, 
            callbacks_period=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-46b32434b6c6> in <module>
# ----> 1 hist_train=model.train(n_iters=10,
#       2             features=x,
#       3             labels=y,
#       4             callbacks_period=2)
#
# ~/Escritorio/Allison/linear_models/_linear_regression.py in train(self, n_iters, features, labels, callbacks_period)
#      56
#      57     for i in range(n_iters):
# ---> 58       predictions=self.foward(features)
#      59       self.bacward(labels, predictions, features)
#      60
#
# ~/Escritorio/Allison/linear_models/_linear_regression.py in foward(self, features)
#      28
#      29   def foward(self,features):
# ---> 30     prediction=self.bias + self.weights@features
#      31     return prediction
#      32
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 100 is different from 1)

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y,s=50)
plt.plot(x,model.predict(x), lw=3, c='red')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-aa7bd19c8f69> in <module>
#       1 plt.figure(figsize=(12,8))
#       2 plt.scatter(x,y,s=50)
# ----> 3 plt.plot(x,model.predict(x), lw=3, c='red')
#
# ~/Escritorio/Allison/linear_models/_linear_regression.py in predict(self, features)
#      71
#      72   def predict (self,features):
# ---> 73     predictions=self.foward(features)
#      74     return predictions
#      75
#
# ~/Escritorio/Allison/linear_models/_linear_regression.py in foward(self, features)
#      28
#      29   def foward(self,features):
# ---> 30     prediction=self.bias + self.weights@features
#      31     return prediction
#      32
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 100 is different from 1)
