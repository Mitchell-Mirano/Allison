# %% [markdown]
# ## A comparison between the different regressors

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import LinearRegression
from allison.regression import PolinomicRegression
from allison.regression import FunctionalRegression
from allison.utils.functions.loss import mean_squared_error
from allison.utils.metrics import r2_score

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,1000)
y=x+ 2*np.sin(x) +0.5*np.random.randn(1000)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression(loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 56.332% 	 r2_score: -1280.83%
#
# Iter:	10	==================================================>	 mean_squared_error: 7.491% 	 r2_score: 63.42%
#
# Iter:	15	==================================================>	 mean_squared_error: 2.588% 	 r2_score: 90.91%
#
# Iter:	20	==================================================>	 mean_squared_error: 2.143% 	 r2_score: 93.16%
#
# Iter:	25	==================================================>	 mean_squared_error: 2.118% 	 r2_score: 93.44%
#
# Iter:	30	==================================================>	 mean_squared_error: 2.123% 	 r2_score: 93.49%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression(
                base_functions=["x","sinx"],
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score
)

                
history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 317.797% 	 r2_score: -2955.89%
#
# Iter:	10	==================================================>	 mean_squared_error: 259.183% 	 r2_score: -4511.12%
#
# Iter:	15	==================================================>	 mean_squared_error: 211.407% 	 r2_score: -8104.87%
#
# Iter:	20	==================================================>	 mean_squared_error: 172.468% 	 r2_score: -19861.45%
#
# Iter:	25	==================================================>	 mean_squared_error: 140.732% 	 r2_score: -86480.38%
#
# Iter:	30	==================================================>	 mean_squared_error: 114.868% 	 r2_score: -52553.28%
#
# Iter:	35	==================================================>	 mean_squared_error: 93.791% 	 r2_score: -11197.16%
#
# Iter:	40	==================================================>	 mean_squared_error: 76.616% 	 r2_score: -4061.59%
#
# ...

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression(n_grade=1,
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)
history=model.train(n_iters=200,
                    features=x,
                    labels=y,
                    callbacks_period=10,history_train=True)
# Out:
# Iter:	10	==================================================>	 mean_squared_error: 559.023% 	 r2_score: -645.64%
#
# Iter:	20	==================================================>	 mean_squared_error: 431.289% 	 r2_score: -278.67%
#
# Iter:	30	==================================================>	 mean_squared_error: 372.167% 	 r2_score: -164.92%
#
# Iter:	40	==================================================>	 mean_squared_error: 342.924% 	 r2_score: -117.91%
#
# Iter:	50	==================================================>	 mean_squared_error: 327.642% 	 r2_score: -95.36%
#
# Iter:	60	==================================================>	 mean_squared_error: 319.323% 	 r2_score: -83.59%
#
# Iter:	70	==================================================>	 mean_squared_error: 314.666% 	 r2_score: -77.15%
#
# Iter:	80	==================================================>	 mean_squared_error: 312.011% 	 r2_score: -73.52%
#
# ...

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression(n_grade=2,
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score)

history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    history_train=True)
# Out:
# Iter:	50	==================================================>	 mean_squared_error: 63.550% 	 r2_score: 87.40%
#
# Iter:	100	==================================================>	 mean_squared_error: 63.548% 	 r2_score: 87.40%
#
# Iter:	150	==================================================>	 mean_squared_error: 63.548% 	 r2_score: 87.40%
#
# Iter:	200	==================================================>	 mean_squared_error: 63.548% 	 r2_score: 87.40%
#
# Iter:	250	==================================================>	 mean_squared_error: 63.548% 	 r2_score: 87.40%
#
# Iter:	300	==================================================>	 mean_squared_error: 63.548% 	 r2_score: 87.40%
#
# Iter:	350	==================================================>	 mean_squared_error: 63.548% 	 r2_score: 87.40%
#
# Iter:	400	==================================================>	 mean_squared_error: 63.548% 	 r2_score: 87.40%
#
# ...

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
