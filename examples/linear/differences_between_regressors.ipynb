# %% [markdown]
# ## A comparison between the different regressors

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import LinearRegression
from allison.regression import PolinomicRegression
from allison.regression import FunctionalRegression
from allison.utils.functions.loss import mean_squared_error
from allison.utils.metrics import r2_score

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,100)
y=x+ 2*np.sin(x) +0.5*np.random.randn(100)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression(loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 7.298% 	 r2_score: 66.29%
#
# Iter:	10	==================================================>	 mean_squared_error: 2.523% 	 r2_score: 91.51%
#
# Iter:	15	==================================================>	 mean_squared_error: 2.074% 	 r2_score: 93.64%
#
# Iter:	20	==================================================>	 mean_squared_error: 2.043% 	 r2_score: 93.92%
#
# Iter:	25	==================================================>	 mean_squared_error: 2.045% 	 r2_score: 93.97%
#
# Iter:	30	==================================================>	 mean_squared_error: 2.047% 	 r2_score: 93.98%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression()
model.optimizers(base_functions=["x","sinx"],
                loss_function=mean_squared_error,
                lr=0.001,
                metrics=r2_score)
                
history=model.train(n_iters=30,
                    features=x,
                    labels=y,
                    callbacks_period=5)
# Out:
# Iter:	5	==================================================>	 r2_score:	84.88%
#
#
# Iter:	10	==================================================>	 r2_score:	95.61%
#
#
# Iter:	15	==================================================>	 r2_score:	96.65%
#
#
# Iter:	20	==================================================>	 r2_score:	96.80%
#
#
# Iter:	25	==================================================>	 r2_score:	96.82%
#
#
# Iter:	30	==================================================>	 r2_score:	96.83%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression(n_grade=1,
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)
history=model.train(n_iters=100,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 1138.338% 	 r2_score: -18765.34%
#
# Iter:	10	==================================================>	 mean_squared_error: 862.313% 	 r2_score: -3419.26%
#
# Iter:	15	==================================================>	 mean_squared_error: 686.113% 	 r2_score: -1358.27%
#
# Iter:	20	==================================================>	 mean_squared_error: 571.803% 	 r2_score: -725.81%
#
# Iter:	25	==================================================>	 mean_squared_error: 496.359% 	 r2_score: -456.94%
#
# Iter:	30	==================================================>	 mean_squared_error: 445.674% 	 r2_score: -320.29%
#
# Iter:	35	==================================================>	 mean_squared_error: 411.017% 	 r2_score: -242.56%
#
# Iter:	40	==================================================>	 mean_squared_error: 386.915% 	 r2_score: -194.81%
#
# Iter:	45	==================================================>	 mean_squared_error: 369.887% 	 r2_score: -163.82%
#
# Iter:	50	==================================================>	 mean_squared_error: 357.686% 	 r2_score: -142.88%
#
# Iter:	55	==================================================>	 mean_squared_error: 348.835% 	 r2_score: -128.31%
#
# Iter:	60	==================================================>	 mean_squared_error: 342.345% 	 r2_score: -117.93%
#
# Iter:	65	==================================================>	 mean_squared_error: 337.544% 	 r2_score: -110.41%
#
# Iter:	70	==================================================>	 mean_squared_error: 333.967% 	 r2_score: -104.89%
#
# Iter:	75	==================================================>	 mean_squared_error: 331.286% 	 r2_score: -100.80%
#
# Iter:	80	==================================================>	 mean_squared_error: 329.268% 	 r2_score: -97.75%
#
# Iter:	85	==================================================>	 mean_squared_error: 327.742% 	 r2_score: -95.45%
#
# Iter:	90	==================================================>	 mean_squared_error: 326.585% 	 r2_score: -93.72%
#
# Iter:	95	==================================================>	 mean_squared_error: 325.707% 	 r2_score: -92.41%
#
# Iter:	100	==================================================>	 mean_squared_error: 325.038% 	 r2_score: -91.41%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression(n_grade=2,
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score)

history=model.train(n_iters=200,
                    features=x,
                    labels=y,
                    history_train=True)
# Out:
# Iter:	20	==================================================>	 mean_squared_error: 85.696% 	 r2_score: 80.89%
#
# Iter:	40	==================================================>	 mean_squared_error: 80.896% 	 r2_score: 82.41%
#
# Iter:	60	==================================================>	 mean_squared_error: 80.871% 	 r2_score: 82.41%
#
# Iter:	80	==================================================>	 mean_squared_error: 80.871% 	 r2_score: 82.41%
#
# Iter:	100	==================================================>	 mean_squared_error: 80.871% 	 r2_score: 82.41%
#
# Iter:	120	==================================================>	 mean_squared_error: 80.871% 	 r2_score: 82.41%
#
# Iter:	140	==================================================>	 mean_squared_error: 80.871% 	 r2_score: 82.41%
#
# Iter:	160	==================================================>	 mean_squared_error: 80.871% 	 r2_score: 82.41%
#
# Iter:	180	==================================================>	 mean_squared_error: 80.871% 	 r2_score: 82.41%
#
# Iter:	200	==================================================>	 mean_squared_error: 80.871% 	 r2_score: 82.41%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
