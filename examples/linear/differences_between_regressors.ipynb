# %% [markdown]
# ## A comparison between the different regressors

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import LinearRegression
from allison.regression import PolinomicRegression
from allison.regression import FunctionalRegression
from allison.utils.functions.loss import mean_squared_error
from allison.utils.metrics import r2_score

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,1000)
y=x+ 2*np.sin(x) +0.5*np.random.randn(1000)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression(loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 21.594% 	 r2_score: -73.91%
#
# Iter:	10	==================================================>	 mean_squared_error: 4.025% 	 r2_score: 84.14%
#
# Iter:	15	==================================================>	 mean_squared_error: 2.322% 	 r2_score: 92.40%
#
# Iter:	20	==================================================>	 mean_squared_error: 2.188% 	 r2_score: 93.23%
#
# Iter:	25	==================================================>	 mean_squared_error: 2.188% 	 r2_score: 93.35%
#
# Iter:	30	==================================================>	 mean_squared_error: 2.193% 	 r2_score: 93.38%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression(
                base_functions=["x","sinx"],
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score
)

                
history=model.train(n_iters=100,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 45.164% 	 r2_score: -630.38%
#
# Iter:	10	==================================================>	 mean_squared_error: 6.846% 	 r2_score: 69.12%
#
# Iter:	15	==================================================>	 mean_squared_error: 3.041% 	 r2_score: 89.68%
#
# Iter:	20	==================================================>	 mean_squared_error: 2.709% 	 r2_score: 91.54%
#
# Iter:	25	==================================================>	 mean_squared_error: 2.696% 	 r2_score: 91.80%
#
# Iter:	30	==================================================>	 mean_squared_error: 2.702% 	 r2_score: 91.86%
#
# Iter:	35	==================================================>	 mean_squared_error: 2.705% 	 r2_score: 91.87%
#
# Iter:	40	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.87%
#
# Iter:	45	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	50	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	55	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	60	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	65	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	70	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	75	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	80	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	85	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	90	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	95	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%
#
# Iter:	100	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.88%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression(n_grade=1,
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)
history=model.train(n_iters=200,
                    features=x,
                    labels=y,
                    callbacks_period=10,history_train=True)
# Out:
# Iter:	10	==================================================>	 mean_squared_error: 827.480% 	 r2_score: -2639.16%
#
# Iter:	20	==================================================>	 mean_squared_error: 555.745% 	 r2_score: -629.06%
#
# Iter:	30	==================================================>	 mean_squared_error: 437.115% 	 r2_score: -287.05%
#
# Iter:	40	==================================================>	 mean_squared_error: 381.548% 	 r2_score: -176.89%
#
# Iter:	50	==================================================>	 mean_squared_error: 353.776% 	 r2_score: -130.43%
#
# Iter:	60	==================================================>	 mean_squared_error: 339.146% 	 r2_score: -107.89%
#
# Iter:	70	==================================================>	 mean_squared_error: 331.137% 	 r2_score: -96.04%
#
# Iter:	80	==================================================>	 mean_squared_error: 326.636% 	 r2_score: -89.53%
#
# Iter:	90	==================================================>	 mean_squared_error: 324.065% 	 r2_score: -85.85%
#
# Iter:	100	==================================================>	 mean_squared_error: 322.581% 	 r2_score: -83.74%
#
# Iter:	110	==================================================>	 mean_squared_error: 321.718% 	 r2_score: -82.52%
#
# Iter:	120	==================================================>	 mean_squared_error: 321.215% 	 r2_score: -81.81%
#
# Iter:	130	==================================================>	 mean_squared_error: 320.922% 	 r2_score: -81.39%
#
# Iter:	140	==================================================>	 mean_squared_error: 320.750% 	 r2_score: -81.15%
#
# Iter:	150	==================================================>	 mean_squared_error: 320.649% 	 r2_score: -81.01%
#
# Iter:	160	==================================================>	 mean_squared_error: 320.590% 	 r2_score: -80.93%
#
# Iter:	170	==================================================>	 mean_squared_error: 320.555% 	 r2_score: -80.88%
#
# Iter:	180	==================================================>	 mean_squared_error: 320.535% 	 r2_score: -80.85%
#
# Iter:	190	==================================================>	 mean_squared_error: 320.523% 	 r2_score: -80.83%
#
# Iter:	200	==================================================>	 mean_squared_error: 320.516% 	 r2_score: -80.82%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression(n_grade=2,
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score)

history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    history_train=True)
# Out:
# Iter:	50	==================================================>	 mean_squared_error: 80.281% 	 r2_score: 82.79%
#
# Iter:	100	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%
#
# Iter:	150	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%
#
# Iter:	200	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%
#
# Iter:	250	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%
#
# Iter:	300	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%
#
# Iter:	350	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%
#
# Iter:	400	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%
#
# Iter:	450	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%
#
# Iter:	500	==================================================>	 mean_squared_error: 80.280% 	 r2_score: 82.79%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
