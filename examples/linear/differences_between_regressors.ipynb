# %% [markdown]
# ## A comparison between the different regressors

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import LinearRegression
from allison.regression import PolinomicRegression
from allison.regression import FunctionalRegression
from allison.utils.functions.loss import mean_squared_error
from allison.utils.metrics import r2_score

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,1000)
y=x+ 2*np.sin(x) +0.5*np.random.randn(1000)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression(loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 105.574% 	 r2_score: -27629.36%
#
# Iter:	10	==================================================>	 mean_squared_error: 12.618% 	 r2_score: 23.33%
#
# Iter:	15	==================================================>	 mean_squared_error: 3.084% 	 r2_score: 88.46%
#
# Iter:	20	==================================================>	 mean_squared_error: 2.150% 	 r2_score: 92.97%
#
# Iter:	25	==================================================>	 mean_squared_error: 2.074% 	 r2_score: 93.50%
#
# Iter:	30	==================================================>	 mean_squared_error: 2.072% 	 r2_score: 93.59%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression(
                base_functions=["x","sinx"],
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score
)

                
history=model.train(n_iters=100,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 11.819% 	 r2_score: 27.56%
#
# Iter:	10	==================================================>	 mean_squared_error: 1.816% 	 r2_score: 93.18%
#
# Iter:	15	==================================================>	 mean_squared_error: 0.813% 	 r2_score: 97.34%
#
# Iter:	20	==================================================>	 mean_squared_error: 0.722% 	 r2_score: 97.73%
#
# Iter:	25	==================================================>	 mean_squared_error: 0.718% 	 r2_score: 97.78%
#
# Iter:	30	==================================================>	 mean_squared_error: 0.719% 	 r2_score: 97.78%
#
# Iter:	35	==================================================>	 mean_squared_error: 0.719% 	 r2_score: 97.78%
#
# Iter:	40	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	45	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	50	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	55	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	60	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	65	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	70	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	75	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	80	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	85	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	90	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	95	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%
#
# Iter:	100	==================================================>	 mean_squared_error: 0.720% 	 r2_score: 97.78%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression(n_grade=1,
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)
history=model.train(n_iters=200,
                    features=x,
                    labels=y,
                    callbacks_period=10,history_train=True)
# Out:
# Iter:	10	==================================================>	 mean_squared_error: 994.504% 	 r2_score: -6921.30%
#
# Iter:	20	==================================================>	 mean_squared_error: 638.130% 	 r2_score: -1016.05%
#
# Iter:	30	==================================================>	 mean_squared_error: 485.286% 	 r2_score: -406.51%
#
# Iter:	40	==================================================>	 mean_squared_error: 414.955% 	 r2_score: -237.18%
#
# Iter:	50	==================================================>	 mean_squared_error: 380.348% 	 r2_score: -170.46%
#
# Iter:	60	==================================================>	 mean_squared_error: 362.336% 	 r2_score: -139.21%
#
# Iter:	70	==================================================>	 mean_squared_error: 352.559% 	 r2_score: -123.12%
#
# Iter:	80	==================================================>	 mean_squared_error: 347.097% 	 r2_score: -114.37%
#
# Iter:	90	==================================================>	 mean_squared_error: 343.987% 	 r2_score: -109.46%
#
# Iter:	100	==================================================>	 mean_squared_error: 342.195% 	 r2_score: -106.66%
#
# Iter:	110	==================================================>	 mean_squared_error: 341.156% 	 r2_score: -105.04%
#
# Iter:	120	==================================================>	 mean_squared_error: 340.550% 	 r2_score: -104.10%
#
# Iter:	130	==================================================>	 mean_squared_error: 340.196% 	 r2_score: -103.55%
#
# Iter:	140	==================================================>	 mean_squared_error: 339.989% 	 r2_score: -103.23%
#
# Iter:	150	==================================================>	 mean_squared_error: 339.868% 	 r2_score: -103.04%
#
# Iter:	160	==================================================>	 mean_squared_error: 339.797% 	 r2_score: -102.93%
#
# Iter:	170	==================================================>	 mean_squared_error: 339.756% 	 r2_score: -102.86%
#
# Iter:	180	==================================================>	 mean_squared_error: 339.731% 	 r2_score: -102.83%
#
# Iter:	190	==================================================>	 mean_squared_error: 339.717% 	 r2_score: -102.81%
#
# Iter:	200	==================================================>	 mean_squared_error: 339.709% 	 r2_score: -102.79%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression(n_grade=2,
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score)

history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    history_train=True)
# Out:
# Iter:	50	==================================================>	 mean_squared_error: 88.514% 	 r2_score: 80.56%
#
# Iter:	100	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%
#
# Iter:	150	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%
#
# Iter:	200	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%
#
# Iter:	250	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%
#
# Iter:	300	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%
#
# Iter:	350	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%
#
# Iter:	400	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%
#
# Iter:	450	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%
#
# Iter:	500	==================================================>	 mean_squared_error: 88.512% 	 r2_score: 80.56%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
