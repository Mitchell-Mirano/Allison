# %% [markdown]
# ## A comparison between the different regressors

# %%
# !cd ..
# Out:
# /home/mitchellmirano/Desktop/Allison

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from linear_models.linear_regression import LinearRegression
from linear_models.polinomic_regression import PolinomicRegression
from linear_models.functional_regression import FunctionalRegression
from utils.functions.loss import mean_square_error
from utils.metrics import r2_score, recall

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,100)
y=x+ 2*np.sin(x) +0.5*np.random.randn(100)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression()

model.optimizers(loss_function=mean_square_error,
                lr=0.001,
                metrics=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5)
# Out:
# Iter:	5	==================================================>	 r2_score:	78.39%
#
#
# Iter:	10	==================================================>	 r2_score:	91.27%
#
#
# Iter:	15	==================================================>	 r2_score:	92.89%
#
#
# Iter:	20	==================================================>	 r2_score:	93.15%
#
#
# Iter:	25	==================================================>	 r2_score:	93.20%
#
#
# Iter:	30	==================================================>	 r2_score:	93.22%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression()
model.optimizers(base_functions=["x","sinx"],
                loss_function=mean_square_error,
                lr=0.001,
                metrics=r2_score)
                
history=model.train(n_iters=30,
                    features=x,
                    labels=y,
                    callbacks_period=5)
# Out:
# Iter:	5	==================================================>	 r2_score:	96.01%
#
#
# Iter:	10	==================================================>	 r2_score:	97.22%
#
#
# Iter:	15	==================================================>	 r2_score:	97.30%
#
#
# Iter:	20	==================================================>	 r2_score:	97.30%
#
#
# Iter:	25	==================================================>	 r2_score:	97.29%
#
#
# Iter:	30	==================================================>	 r2_score:	97.29%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression()
model.optimizers(n_grade=1,
                loss_function=mean_square_error,
                lr=0.01,
                metrics=r2_score)
history=model.train(n_iters=30,
                    features=x,
                    labels=y,
                    callbacks_period=5)
# Out:
# Iter:	5	==================================================>	 r2_score:	63.65%
#
#
# Iter:	10	==================================================>	 r2_score:	66.55%
#
#
# Iter:	15	==================================================>	 r2_score:	66.62%
#
#
# Iter:	20	==================================================>	 r2_score:	66.62%
#
#
# Iter:	25	==================================================>	 r2_score:	66.62%
#
#
# Iter:	30	==================================================>	 r2_score:	66.62%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression()
model.optimizers(n_grade=2,
                loss_function=mean_square_error,
                lr=0.0001,
                metrics=r2_score)
history=model.train(n_iters=100,
                    features=x,
                    labels=y,
                    callbacks_period=20)
# Out:
# Iter:	20	==================================================>	 r2_score:	91.34%
#
#
# Iter:	40	==================================================>	 r2_score:	91.96%
#
#
# Iter:	60	==================================================>	 r2_score:	91.97%
#
#
# Iter:	80	==================================================>	 r2_score:	91.97%
#
#
# Iter:	100	==================================================>	 r2_score:	91.97%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
