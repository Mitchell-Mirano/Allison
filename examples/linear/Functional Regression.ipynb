# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import FunctionalRegression
from allison.utils.functions.loss import mean_squared_error
from allison.utils.metrics import r2_score

# %%
x=np.linspace(0,20,1000)
y=x+ 2*np.sin(x) +0.5*np.random.randn(1000)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=FunctionalRegression(
                base_functions=["sinx","x"],
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score
)

                
history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 0.708% 	 r2_score: 97.58%
#
# Iter:	10	==================================================>	 mean_squared_error: 0.398% 	 r2_score: 98.74%
#
# Iter:	15	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.85%
#
# Iter:	20	==================================================>	 mean_squared_error: 0.370% 	 r2_score: 98.86%
#
# Iter:	25	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	30	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	35	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	40	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	45	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	50	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	55	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	60	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	65	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	70	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	75	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	80	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	85	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	90	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	95	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	100	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	105	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	110	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	115	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	120	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	125	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	130	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	135	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	140	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	145	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	150	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	155	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	160	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	165	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	170	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	175	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	180	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	185	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	190	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	195	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	200	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	205	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	210	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	215	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	220	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	225	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	230	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	235	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	240	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	245	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	250	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	255	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	260	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	265	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	270	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	275	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	280	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	285	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	290	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	295	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	300	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	305	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	310	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	315	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	320	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	325	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	330	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	335	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	340	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	345	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	350	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	355	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	360	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	365	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	370	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	375	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	380	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	385	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	390	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	395	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	400	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	405	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	410	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	415	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	420	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	425	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	430	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	435	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	440	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	445	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	450	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	455	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	460	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	465	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	470	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	475	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	480	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	485	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	490	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	495	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%
#
# Iter:	500	==================================================>	 mean_squared_error: 0.371% 	 r2_score: 98.86%

# %%
y_pred=model.predict(x)
r2 = model.metric(y, y_pred)
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
plt.title(f'Functional Regression on Test Data(R2:{r2*100:.2f}%)')
# Out:
# Text(0.5, 1.0, 'Functional Regression on Test Data(R2:98.86%)')
