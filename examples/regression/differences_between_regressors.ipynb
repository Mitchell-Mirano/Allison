# %% [markdown]
# ## A comparison between the different regressors

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import LinearRegression
from allison.regression import PolinomicRegression
from allison.regression import FunctionalRegression
from allison.regression.loss import mean_squared_error
from allison.metrics import r2_score

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,1000)
y=x+ 2*np.sin(x) +0.5*np.random.randn(1000)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression(loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 12.954% 	 r2_score: 61.17%
#
# Iter:	10	==================================================>	 mean_squared_error: 3.204% 	 r2_score: 90.40%
#
# Iter:	15	==================================================>	 mean_squared_error: 2.275% 	 r2_score: 93.18%
#
# Iter:	20	==================================================>	 mean_squared_error: 2.208% 	 r2_score: 93.38%
#
# Iter:	25	==================================================>	 mean_squared_error: 2.210% 	 r2_score: 93.38%
#
# Iter:	30	==================================================>	 mean_squared_error: 2.214% 	 r2_score: 93.37%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression(
                base_functions=["x","sinx"],
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score
)

                
history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 101.222% 	 r2_score: -203.40%
#
# Iter:	10	==================================================>	 mean_squared_error: 82.708% 	 r2_score: -147.90%
#
# Iter:	15	==================================================>	 mean_squared_error: 67.603% 	 r2_score: -102.63%
#
# Iter:	20	==================================================>	 mean_squared_error: 55.279% 	 r2_score: -65.69%
#
# Iter:	25	==================================================>	 mean_squared_error: 45.223% 	 r2_score: -35.55%
#
# Iter:	30	==================================================>	 mean_squared_error: 37.016% 	 r2_score: -10.95%
#
# Iter:	35	==================================================>	 mean_squared_error: 30.319% 	 r2_score: 9.12%
#
# Iter:	40	==================================================>	 mean_squared_error: 24.853% 	 r2_score: 25.51%
#
# Iter:	45	==================================================>	 mean_squared_error: 20.392% 	 r2_score: 38.88%
#
# Iter:	50	==================================================>	 mean_squared_error: 16.749% 	 r2_score: 49.80%
#
# Iter:	55	==================================================>	 mean_squared_error: 13.776% 	 r2_score: 58.71%
#
# Iter:	60	==================================================>	 mean_squared_error: 11.348% 	 r2_score: 65.99%
#
# Iter:	65	==================================================>	 mean_squared_error: 9.365% 	 r2_score: 71.93%
#
# Iter:	70	==================================================>	 mean_squared_error: 7.745% 	 r2_score: 76.79%
#
# Iter:	75	==================================================>	 mean_squared_error: 6.421% 	 r2_score: 80.75%
#
# Iter:	80	==================================================>	 mean_squared_error: 5.340% 	 r2_score: 83.99%
#
# Iter:	85	==================================================>	 mean_squared_error: 4.457% 	 r2_score: 86.64%
#
# Iter:	90	==================================================>	 mean_squared_error: 3.734% 	 r2_score: 88.81%
#
# Iter:	95	==================================================>	 mean_squared_error: 3.143% 	 r2_score: 90.58%
#
# Iter:	100	==================================================>	 mean_squared_error: 2.660% 	 r2_score: 92.03%
#
# Iter:	105	==================================================>	 mean_squared_error: 2.265% 	 r2_score: 93.21%
#
# Iter:	110	==================================================>	 mean_squared_error: 1.941% 	 r2_score: 94.18%
#
# Iter:	115	==================================================>	 mean_squared_error: 1.676% 	 r2_score: 94.98%
#
# Iter:	120	==================================================>	 mean_squared_error: 1.459% 	 r2_score: 95.63%
#
# Iter:	125	==================================================>	 mean_squared_error: 1.281% 	 r2_score: 96.16%
#
# Iter:	130	==================================================>	 mean_squared_error: 1.135% 	 r2_score: 96.60%
#
# Iter:	135	==================================================>	 mean_squared_error: 1.016% 	 r2_score: 96.96%
#
# Iter:	140	==================================================>	 mean_squared_error: 0.917% 	 r2_score: 97.25%
#
# Iter:	145	==================================================>	 mean_squared_error: 0.837% 	 r2_score: 97.49%
#
# Iter:	150	==================================================>	 mean_squared_error: 0.770% 	 r2_score: 97.69%
#
# Iter:	155	==================================================>	 mean_squared_error: 0.716% 	 r2_score: 97.86%
#
# Iter:	160	==================================================>	 mean_squared_error: 0.671% 	 r2_score: 97.99%
#
# Iter:	165	==================================================>	 mean_squared_error: 0.634% 	 r2_score: 98.10%
#
# Iter:	170	==================================================>	 mean_squared_error: 0.603% 	 r2_score: 98.19%
#
# Iter:	175	==================================================>	 mean_squared_error: 0.578% 	 r2_score: 98.27%
#
# Iter:	180	==================================================>	 mean_squared_error: 0.557% 	 r2_score: 98.33%
#
# Iter:	185	==================================================>	 mean_squared_error: 0.539% 	 r2_score: 98.38%
#
# Iter:	190	==================================================>	 mean_squared_error: 0.525% 	 r2_score: 98.43%
#
# Iter:	195	==================================================>	 mean_squared_error: 0.513% 	 r2_score: 98.46%
#
# Iter:	200	==================================================>	 mean_squared_error: 0.503% 	 r2_score: 98.49%
#
# Iter:	205	==================================================>	 mean_squared_error: 0.495% 	 r2_score: 98.52%
#
# Iter:	210	==================================================>	 mean_squared_error: 0.488% 	 r2_score: 98.54%
#
# Iter:	215	==================================================>	 mean_squared_error: 0.482% 	 r2_score: 98.55%
#
# Iter:	220	==================================================>	 mean_squared_error: 0.478% 	 r2_score: 98.57%
#
# Iter:	225	==================================================>	 mean_squared_error: 0.473% 	 r2_score: 98.58%
#
# Iter:	230	==================================================>	 mean_squared_error: 0.470% 	 r2_score: 98.59%
#
# Iter:	235	==================================================>	 mean_squared_error: 0.467% 	 r2_score: 98.60%
#
# Iter:	240	==================================================>	 mean_squared_error: 0.465% 	 r2_score: 98.61%
#
# Iter:	245	==================================================>	 mean_squared_error: 0.463% 	 r2_score: 98.61%
#
# Iter:	250	==================================================>	 mean_squared_error: 0.461% 	 r2_score: 98.62%
#
# Iter:	255	==================================================>	 mean_squared_error: 0.459% 	 r2_score: 98.62%
#
# Iter:	260	==================================================>	 mean_squared_error: 0.458% 	 r2_score: 98.63%
#
# Iter:	265	==================================================>	 mean_squared_error: 0.457% 	 r2_score: 98.63%
#
# Iter:	270	==================================================>	 mean_squared_error: 0.456% 	 r2_score: 98.63%
#
# Iter:	275	==================================================>	 mean_squared_error: 0.455% 	 r2_score: 98.64%
#
# Iter:	280	==================================================>	 mean_squared_error: 0.455% 	 r2_score: 98.64%
#
# Iter:	285	==================================================>	 mean_squared_error: 0.454% 	 r2_score: 98.64%
#
# Iter:	290	==================================================>	 mean_squared_error: 0.453% 	 r2_score: 98.64%
#
# Iter:	295	==================================================>	 mean_squared_error: 0.453% 	 r2_score: 98.64%
#
# Iter:	300	==================================================>	 mean_squared_error: 0.453% 	 r2_score: 98.64%
#
# Iter:	305	==================================================>	 mean_squared_error: 0.452% 	 r2_score: 98.64%
#
# Iter:	310	==================================================>	 mean_squared_error: 0.452% 	 r2_score: 98.65%
#
# Iter:	315	==================================================>	 mean_squared_error: 0.452% 	 r2_score: 98.65%
#
# Iter:	320	==================================================>	 mean_squared_error: 0.451% 	 r2_score: 98.65%
#
# Iter:	325	==================================================>	 mean_squared_error: 0.451% 	 r2_score: 98.65%
#
# Iter:	330	==================================================>	 mean_squared_error: 0.451% 	 r2_score: 98.65%
#
# Iter:	335	==================================================>	 mean_squared_error: 0.451% 	 r2_score: 98.65%
#
# Iter:	340	==================================================>	 mean_squared_error: 0.451% 	 r2_score: 98.65%
#
# Iter:	345	==================================================>	 mean_squared_error: 0.451% 	 r2_score: 98.65%
#
# Iter:	350	==================================================>	 mean_squared_error: 0.451% 	 r2_score: 98.65%
#
# Iter:	355	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	360	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	365	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	370	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	375	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	380	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	385	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	390	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	395	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	400	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	405	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	410	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	415	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	420	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	425	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	430	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	435	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	440	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	445	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	450	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	455	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	460	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	465	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	470	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	475	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	480	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	485	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	490	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	495	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%
#
# Iter:	500	==================================================>	 mean_squared_error: 0.450% 	 r2_score: 98.65%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression(n_grade=1,
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)
history=model.train(n_iters=200,
                    features=x,
                    labels=y,
                    callbacks_period=10,history_train=True)
# Out:
# Iter:	10	==================================================>	 mean_squared_error: 1084.587% 	 r2_score: -20.02%
#
# Iter:	20	==================================================>	 mean_squared_error: 662.141% 	 r2_score: 26.73%
#
# Iter:	30	==================================================>	 mean_squared_error: 484.047% 	 r2_score: 46.44%
#
# Iter:	40	==================================================>	 mean_squared_error: 403.548% 	 r2_score: 55.34%
#
# Iter:	50	==================================================>	 mean_squared_error: 364.573% 	 r2_score: 59.66%
#
# Iter:	60	==================================================>	 mean_squared_error: 344.547% 	 r2_score: 61.87%
#
# Iter:	70	==================================================>	 mean_squared_error: 333.778% 	 r2_score: 63.06%
#
# Iter:	80	==================================================>	 mean_squared_error: 327.799% 	 r2_score: 63.73%
#
# Iter:	90	==================================================>	 mean_squared_error: 324.407% 	 r2_score: 64.10%
#
# Iter:	100	==================================================>	 mean_squared_error: 322.459% 	 r2_score: 64.32%
#
# Iter:	110	==================================================>	 mean_squared_error: 321.330% 	 r2_score: 64.44%
#
# Iter:	120	==================================================>	 mean_squared_error: 320.673% 	 r2_score: 64.51%
#
# Iter:	130	==================================================>	 mean_squared_error: 320.289% 	 r2_score: 64.56%
#
# Iter:	140	==================================================>	 mean_squared_error: 320.065% 	 r2_score: 64.58%
#
# Iter:	150	==================================================>	 mean_squared_error: 319.934% 	 r2_score: 64.60%
#
# Iter:	160	==================================================>	 mean_squared_error: 319.857% 	 r2_score: 64.60%
#
# Iter:	170	==================================================>	 mean_squared_error: 319.812% 	 r2_score: 64.61%
#
# Iter:	180	==================================================>	 mean_squared_error: 319.785% 	 r2_score: 64.61%
#
# Iter:	190	==================================================>	 mean_squared_error: 319.770% 	 r2_score: 64.61%
#
# Iter:	200	==================================================>	 mean_squared_error: 319.761% 	 r2_score: 64.62%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression(n_grade=2,
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score)

history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    history_train=True)
# Out:
# Iter:	50	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	100	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	150	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	200	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	250	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	300	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	350	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	400	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	450	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%
#
# Iter:	500	==================================================>	 mean_squared_error: 155.310% 	 r2_score: 82.81%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
