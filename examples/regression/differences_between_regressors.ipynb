# %% [markdown]
# ## A comparison between the different regressors

# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import LinearRegression
from allison.regression import PolinomicRegression
from allison.regression import FunctionalRegression
from allison.regression.loss import mean_squared_error
from allison.metrics import r2_score

# %% [markdown]
# ### Linear Regression vs FunctionalRegression

# %%
x=np.linspace(0,20,1000)
y=x+ 2*np.sin(x) +0.5*np.random.randn(1000)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=LinearRegression(loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)

history=model.train(n_iters=30,
            features=x,
            labels=y,
            callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 39.857% 	 r2_score: -469.31%
#
# Iter:	10	==================================================>	 mean_squared_error: 5.922% 	 r2_score: 73.63%
#
# Iter:	15	==================================================>	 mean_squared_error: 2.546% 	 r2_score: 91.32%
#
# Iter:	20	==================================================>	 mean_squared_error: 2.250% 	 r2_score: 92.92%
#
# Iter:	25	==================================================>	 mean_squared_error: 2.237% 	 r2_score: 93.13%
#
# Iter:	30	==================================================>	 mean_squared_error: 2.242% 	 r2_score: 93.17%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=FunctionalRegression(
                base_functions=["x","sinx"],
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score
)

                
history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 382.386% 	 r2_score: -2067.69%
#
# Iter:	10	==================================================>	 mean_squared_error: 311.884% 	 r2_score: -2804.80%
#
# Iter:	15	==================================================>	 mean_squared_error: 254.400% 	 r2_score: -4120.87%
#
# Iter:	20	==================================================>	 mean_squared_error: 207.532% 	 r2_score: -6778.27%
#
# Iter:	25	==================================================>	 mean_squared_error: 169.319% 	 r2_score: -12799.64%
#
# Iter:	30	==================================================>	 mean_squared_error: 138.163% 	 r2_score: -22941.23%
#
# Iter:	35	==================================================>	 mean_squared_error: 112.761% 	 r2_score: -17809.28%
#
# Iter:	40	==================================================>	 mean_squared_error: 92.051% 	 r2_score: -7532.03%
#
# Iter:	45	==================================================>	 mean_squared_error: 75.166% 	 r2_score: -3356.44%
#
# Iter:	50	==================================================>	 mean_squared_error: 61.400% 	 r2_score: -1698.18%
#
# Iter:	55	==================================================>	 mean_squared_error: 50.178% 	 r2_score: -938.43%
#
# Iter:	60	==================================================>	 mean_squared_error: 41.028% 	 r2_score: -545.61%
#
# Iter:	65	==================================================>	 mean_squared_error: 33.569% 	 r2_score: -323.42%
#
# Iter:	70	==================================================>	 mean_squared_error: 27.489% 	 r2_score: -189.04%
#
# Iter:	75	==================================================>	 mean_squared_error: 22.532% 	 r2_score: -103.53%
#
# Iter:	80	==================================================>	 mean_squared_error: 18.491% 	 r2_score: -46.91%
#
# Iter:	85	==================================================>	 mean_squared_error: 15.197% 	 r2_score: -8.22%
#
# Iter:	90	==================================================>	 mean_squared_error: 12.512% 	 r2_score: 18.91%
#
# Iter:	95	==================================================>	 mean_squared_error: 10.324% 	 r2_score: 38.33%
#
# Iter:	100	==================================================>	 mean_squared_error: 8.540% 	 r2_score: 52.48%
#
# Iter:	105	==================================================>	 mean_squared_error: 7.087% 	 r2_score: 62.94%
#
# Iter:	110	==================================================>	 mean_squared_error: 5.902% 	 r2_score: 70.77%
#
# Iter:	115	==================================================>	 mean_squared_error: 4.937% 	 r2_score: 76.70%
#
# Iter:	120	==================================================>	 mean_squared_error: 4.150% 	 r2_score: 81.22%
#
# Iter:	125	==================================================>	 mean_squared_error: 3.509% 	 r2_score: 84.71%
#
# Iter:	130	==================================================>	 mean_squared_error: 2.987% 	 r2_score: 87.41%
#
# Iter:	135	==================================================>	 mean_squared_error: 2.561% 	 r2_score: 89.52%
#
# Iter:	140	==================================================>	 mean_squared_error: 2.214% 	 r2_score: 91.17%
#
# Iter:	145	==================================================>	 mean_squared_error: 1.932% 	 r2_score: 92.48%
#
# Iter:	150	==================================================>	 mean_squared_error: 1.702% 	 r2_score: 93.51%
#
# Iter:	155	==================================================>	 mean_squared_error: 1.515% 	 r2_score: 94.33%
#
# Iter:	160	==================================================>	 mean_squared_error: 1.362% 	 r2_score: 94.99%
#
# Iter:	165	==================================================>	 mean_squared_error: 1.238% 	 r2_score: 95.51%
#
# Iter:	170	==================================================>	 mean_squared_error: 1.137% 	 r2_score: 95.93%
#
# Iter:	175	==================================================>	 mean_squared_error: 1.055% 	 r2_score: 96.27%
#
# Iter:	180	==================================================>	 mean_squared_error: 0.988% 	 r2_score: 96.55%
#
# Iter:	185	==================================================>	 mean_squared_error: 0.934% 	 r2_score: 96.77%
#
# Iter:	190	==================================================>	 mean_squared_error: 0.890% 	 r2_score: 96.95%
#
# Iter:	195	==================================================>	 mean_squared_error: 0.854% 	 r2_score: 97.10%
#
# Iter:	200	==================================================>	 mean_squared_error: 0.825% 	 r2_score: 97.21%
#
# Iter:	205	==================================================>	 mean_squared_error: 0.801% 	 r2_score: 97.31%
#
# Iter:	210	==================================================>	 mean_squared_error: 0.782% 	 r2_score: 97.39%
#
# Iter:	215	==================================================>	 mean_squared_error: 0.766% 	 r2_score: 97.46%
#
# Iter:	220	==================================================>	 mean_squared_error: 0.753% 	 r2_score: 97.51%
#
# Iter:	225	==================================================>	 mean_squared_error: 0.743% 	 r2_score: 97.56%
#
# Iter:	230	==================================================>	 mean_squared_error: 0.735% 	 r2_score: 97.59%
#
# Iter:	235	==================================================>	 mean_squared_error: 0.728% 	 r2_score: 97.62%
#
# Iter:	240	==================================================>	 mean_squared_error: 0.722% 	 r2_score: 97.65%
#
# Iter:	245	==================================================>	 mean_squared_error: 0.718% 	 r2_score: 97.67%
#
# Iter:	250	==================================================>	 mean_squared_error: 0.714% 	 r2_score: 97.69%
#
# Iter:	255	==================================================>	 mean_squared_error: 0.712% 	 r2_score: 97.70%
#
# Iter:	260	==================================================>	 mean_squared_error: 0.709% 	 r2_score: 97.71%
#
# Iter:	265	==================================================>	 mean_squared_error: 0.707% 	 r2_score: 97.72%
#
# Iter:	270	==================================================>	 mean_squared_error: 0.706% 	 r2_score: 97.73%
#
# Iter:	275	==================================================>	 mean_squared_error: 0.705% 	 r2_score: 97.74%
#
# Iter:	280	==================================================>	 mean_squared_error: 0.704% 	 r2_score: 97.74%
#
# Iter:	285	==================================================>	 mean_squared_error: 0.703% 	 r2_score: 97.75%
#
# Iter:	290	==================================================>	 mean_squared_error: 0.702% 	 r2_score: 97.75%
#
# Iter:	295	==================================================>	 mean_squared_error: 0.702% 	 r2_score: 97.76%
#
# Iter:	300	==================================================>	 mean_squared_error: 0.701% 	 r2_score: 97.76%
#
# Iter:	305	==================================================>	 mean_squared_error: 0.701% 	 r2_score: 97.76%
#
# Iter:	310	==================================================>	 mean_squared_error: 0.701% 	 r2_score: 97.77%
#
# Iter:	315	==================================================>	 mean_squared_error: 0.701% 	 r2_score: 97.77%
#
# Iter:	320	==================================================>	 mean_squared_error: 0.701% 	 r2_score: 97.77%
#
# Iter:	325	==================================================>	 mean_squared_error: 0.701% 	 r2_score: 97.77%
#
# Iter:	330	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.77%
#
# Iter:	335	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.77%
#
# Iter:	340	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.77%
#
# Iter:	345	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	350	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	355	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	360	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	365	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	370	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	375	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	380	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	385	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	390	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	395	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	400	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	405	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	410	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	415	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	420	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	425	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	430	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	435	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	440	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	445	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	450	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	455	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	460	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	465	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	470	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	475	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	480	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	485	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	490	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	495	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%
#
# Iter:	500	==================================================>	 mean_squared_error: 0.700% 	 r2_score: 97.78%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %% [markdown]
# ### A polynomial of degree 1 vs a polynomial of degree 2

# %%
x=np.linspace(0,10,100)
y=10-x**2 + 2*np.random.randn(100)
plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=PolinomicRegression(n_grade=1,
                loss_function=mean_squared_error,
                lr=0.001,
                metric=r2_score)
history=model.train(n_iters=200,
                    features=x,
                    labels=y,
                    callbacks_period=10,history_train=True)
# Out:
# Iter:	10	==================================================>	 mean_squared_error: 677.557% 	 r2_score: -1212.25%
#
# Iter:	20	==================================================>	 mean_squared_error: 487.669% 	 r2_score: -410.52%
#
# Iter:	30	==================================================>	 mean_squared_error: 402.385% 	 r2_score: -215.64%
#
# Iter:	40	==================================================>	 mean_squared_error: 361.337% 	 r2_score: -143.55%
#
# Iter:	50	==================================================>	 mean_squared_error: 340.348% 	 r2_score: -110.96%
#
# Iter:	60	==================================================>	 mean_squared_error: 329.101% 	 r2_score: -94.51%
#
# Iter:	70	==================================================>	 mean_squared_error: 322.870% 	 r2_score: -85.68%
#
# Iter:	80	==================================================>	 mean_squared_error: 319.343% 	 r2_score: -80.75%
#
# Iter:	90	==================================================>	 mean_squared_error: 317.317% 	 r2_score: -77.95%
#
# Iter:	100	==================================================>	 mean_squared_error: 316.145% 	 r2_score: -76.34%
#
# Iter:	110	==================================================>	 mean_squared_error: 315.463% 	 r2_score: -75.41%
#
# Iter:	120	==================================================>	 mean_squared_error: 315.064% 	 r2_score: -74.86%
#
# Iter:	130	==================================================>	 mean_squared_error: 314.831% 	 r2_score: -74.54%
#
# Iter:	140	==================================================>	 mean_squared_error: 314.695% 	 r2_score: -74.36%
#
# Iter:	150	==================================================>	 mean_squared_error: 314.615% 	 r2_score: -74.25%
#
# Iter:	160	==================================================>	 mean_squared_error: 314.568% 	 r2_score: -74.18%
#
# Iter:	170	==================================================>	 mean_squared_error: 314.541% 	 r2_score: -74.15%
#
# Iter:	180	==================================================>	 mean_squared_error: 314.525% 	 r2_score: -74.12%
#
# Iter:	190	==================================================>	 mean_squared_error: 314.515% 	 r2_score: -74.11%
#
# Iter:	200	==================================================>	 mean_squared_error: 314.510% 	 r2_score: -74.10%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")

# %%
model=PolinomicRegression(n_grade=2,
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score)

history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    history_train=True)
# Out:
# Iter:	50	==================================================>	 mean_squared_error: 134.166% 	 r2_score: 62.72%
#
# Iter:	100	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%
#
# Iter:	150	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%
#
# Iter:	200	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%
#
# Iter:	250	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%
#
# Iter:	300	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%
#
# Iter:	350	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%
#
# Iter:	400	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%
#
# Iter:	450	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%
#
# Iter:	500	==================================================>	 mean_squared_error: 134.165% 	 r2_score: 62.72%

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
