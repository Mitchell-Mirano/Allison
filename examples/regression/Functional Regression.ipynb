# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import FunctionalRegression
from allison.regression.loss import mean_squared_error
from allison.metrics import r2_score

# %%
x=np.linspace(0,20,1000)
y=x+ 2*np.sin(x) +0.5*np.random.randn(1000)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=FunctionalRegression(
                base_functions=["sinx","x"],
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score
)

                
history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 350.885% 	 r2_score: -2490.87%
#
# Iter:	10	==================================================>	 mean_squared_error: 286.147% 	 r2_score: -3595.87%
#
# Iter:	15	==================================================>	 mean_squared_error: 233.379% 	 r2_score: -5872.46%
#
# Iter:	20	==================================================>	 mean_squared_error: 190.370% 	 r2_score: -11879.74%
#
# Iter:	25	==================================================>	 mean_squared_error: 155.315% 	 r2_score: -36142.39%
#
# Iter:	30	==================================================>	 mean_squared_error: 126.746% 	 r2_score: -89547.28%
#
# Iter:	35	==================================================>	 mean_squared_error: 103.463% 	 r2_score: -20491.83%
#
# Iter:	40	==================================================>	 mean_squared_error: 84.490% 	 r2_score: -6231.94%
#
# Iter:	45	==================================================>	 mean_squared_error: 69.029% 	 r2_score: -2663.36%
#
# Iter:	50	==================================================>	 mean_squared_error: 56.432% 	 r2_score: -1352.51%
#
# Iter:	55	==================================================>	 mean_squared_error: 46.169% 	 r2_score: -753.09%
#
# Iter:	60	==================================================>	 mean_squared_error: 37.808% 	 r2_score: -439.01%
#
# Iter:	65	==================================================>	 mean_squared_error: 30.998% 	 r2_score: -258.62%
#
# Iter:	70	==================================================>	 mean_squared_error: 25.451% 	 r2_score: -147.97%
#
# Iter:	75	==================================================>	 mean_squared_error: 20.933% 	 r2_score: -76.69%
#
# Iter:	80	==================================================>	 mean_squared_error: 17.255% 	 r2_score: -28.99%
#
# Iter:	85	==================================================>	 mean_squared_error: 14.260% 	 r2_score: 3.89%
#
# Iter:	90	==================================================>	 mean_squared_error: 11.823% 	 r2_score: 27.13%
#
# Iter:	95	==================================================>	 mean_squared_error: 9.839% 	 r2_score: 43.87%
#
# Iter:	100	==================================================>	 mean_squared_error: 8.224% 	 r2_score: 56.14%
#
# Iter:	105	==================================================>	 mean_squared_error: 6.911% 	 r2_score: 65.25%
#
# Iter:	110	==================================================>	 mean_squared_error: 5.843% 	 r2_score: 72.10%
#
# Iter:	115	==================================================>	 mean_squared_error: 4.975% 	 r2_score: 77.31%
#
# Iter:	120	==================================================>	 mean_squared_error: 4.269% 	 r2_score: 81.30%
#
# Iter:	125	==================================================>	 mean_squared_error: 3.696% 	 r2_score: 84.38%
#
# Iter:	130	==================================================>	 mean_squared_error: 3.230% 	 r2_score: 86.78%
#
# Iter:	135	==================================================>	 mean_squared_error: 2.852% 	 r2_score: 88.65%
#
# Iter:	140	==================================================>	 mean_squared_error: 2.545% 	 r2_score: 90.12%
#
# Iter:	145	==================================================>	 mean_squared_error: 2.296% 	 r2_score: 91.29%
#
# Iter:	150	==================================================>	 mean_squared_error: 2.095% 	 r2_score: 92.21%
#
# Iter:	155	==================================================>	 mean_squared_error: 1.931% 	 r2_score: 92.94%
#
# Iter:	160	==================================================>	 mean_squared_error: 1.799% 	 r2_score: 93.53%
#
# Iter:	165	==================================================>	 mean_squared_error: 1.692% 	 r2_score: 94.00%
#
# Iter:	170	==================================================>	 mean_squared_error: 1.606% 	 r2_score: 94.38%
#
# Iter:	175	==================================================>	 mean_squared_error: 1.536% 	 r2_score: 94.69%
#
# Iter:	180	==================================================>	 mean_squared_error: 1.480% 	 r2_score: 94.93%
#
# Iter:	185	==================================================>	 mean_squared_error: 1.435% 	 r2_score: 95.13%
#
# Iter:	190	==================================================>	 mean_squared_error: 1.399% 	 r2_score: 95.30%
#
# Iter:	195	==================================================>	 mean_squared_error: 1.370% 	 r2_score: 95.43%
#
# Iter:	200	==================================================>	 mean_squared_error: 1.346% 	 r2_score: 95.54%
#
# Iter:	205	==================================================>	 mean_squared_error: 1.328% 	 r2_score: 95.63%
#
# Iter:	210	==================================================>	 mean_squared_error: 1.313% 	 r2_score: 95.70%
#
# Iter:	215	==================================================>	 mean_squared_error: 1.301% 	 r2_score: 95.76%
#
# Iter:	220	==================================================>	 mean_squared_error: 1.292% 	 r2_score: 95.81%
#
# Iter:	225	==================================================>	 mean_squared_error: 1.285% 	 r2_score: 95.85%
#
# Iter:	230	==================================================>	 mean_squared_error: 1.279% 	 r2_score: 95.88%
#
# Iter:	235	==================================================>	 mean_squared_error: 1.275% 	 r2_score: 95.91%
#
# Iter:	240	==================================================>	 mean_squared_error: 1.271% 	 r2_score: 95.93%
#
# Iter:	245	==================================================>	 mean_squared_error: 1.269% 	 r2_score: 95.95%
#
# Iter:	250	==================================================>	 mean_squared_error: 1.267% 	 r2_score: 95.97%
#
# Iter:	255	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 95.98%
#
# Iter:	260	==================================================>	 mean_squared_error: 1.264% 	 r2_score: 95.99%
#
# Iter:	265	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.00%
#
# Iter:	270	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.01%
#
# Iter:	275	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.02%
#
# Iter:	280	==================================================>	 mean_squared_error: 1.262% 	 r2_score: 96.02%
#
# Iter:	285	==================================================>	 mean_squared_error: 1.262% 	 r2_score: 96.03%
#
# Iter:	290	==================================================>	 mean_squared_error: 1.262% 	 r2_score: 96.03%
#
# Iter:	295	==================================================>	 mean_squared_error: 1.262% 	 r2_score: 96.03%
#
# Iter:	300	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.04%
#
# Iter:	305	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.04%
#
# Iter:	310	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.04%
#
# Iter:	315	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.04%
#
# Iter:	320	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.05%
#
# Iter:	325	==================================================>	 mean_squared_error: 1.263% 	 r2_score: 96.05%
#
# Iter:	330	==================================================>	 mean_squared_error: 1.264% 	 r2_score: 96.05%
#
# Iter:	335	==================================================>	 mean_squared_error: 1.264% 	 r2_score: 96.05%
#
# Iter:	340	==================================================>	 mean_squared_error: 1.264% 	 r2_score: 96.05%
#
# Iter:	345	==================================================>	 mean_squared_error: 1.264% 	 r2_score: 96.05%
#
# Iter:	350	==================================================>	 mean_squared_error: 1.264% 	 r2_score: 96.05%
#
# Iter:	355	==================================================>	 mean_squared_error: 1.264% 	 r2_score: 96.05%
#
# Iter:	360	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.05%
#
# Iter:	365	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.05%
#
# Iter:	370	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.05%
#
# Iter:	375	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.05%
#
# Iter:	380	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.05%
#
# Iter:	385	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.06%
#
# Iter:	390	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.06%
#
# Iter:	395	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.06%
#
# Iter:	400	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.06%
#
# Iter:	405	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.06%
#
# Iter:	410	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.06%
#
# Iter:	415	==================================================>	 mean_squared_error: 1.265% 	 r2_score: 96.06%
#
# Iter:	420	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	425	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	430	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	435	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	440	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	445	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	450	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	455	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	460	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	465	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	470	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	475	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	480	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	485	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	490	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	495	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%
#
# Iter:	500	==================================================>	 mean_squared_error: 1.266% 	 r2_score: 96.06%

# %%
y_pred=model.predict(x)
r2 = model.metric(y, y_pred)
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
plt.title(f'Functional Regression on Test Data(R2:{r2*100:.2f}%)')
# Out:
# Text(0.5, 1.0, 'Functional Regression on Test Data(R2:96.06%)')
