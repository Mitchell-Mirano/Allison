# %% [markdown]
# ### Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from allison.regression import FunctionalRegression
from allison.regression.loss import mean_squared_error
from allison.metrics import r2_score

# %%
x=np.linspace(0,20,1000)
y=x+ 2*np.sin(x) +0.5*np.random.randn(1000)

plt.figure(figsize=(12,8))
plt.scatter(x,y)

# %%
model=FunctionalRegression(
                base_functions=["sinx","x"],
                loss_function=mean_squared_error,
                lr=0.0001,
                metric=r2_score
)

                
history=model.train(n_iters=500,
                    features=x,
                    labels=y,
                    callbacks_period=5,history_train=True)
# Out:
# Iter:	5	==================================================>	 mean_squared_error: 59.454% 	 r2_score: -81.17%
#
# Iter:	10	==================================================>	 mean_squared_error: 48.808% 	 r2_score: -48.73%
#
# Iter:	15	==================================================>	 mean_squared_error: 40.144% 	 r2_score: -22.33%
#
# Iter:	20	==================================================>	 mean_squared_error: 33.095% 	 r2_score: -0.85%
#
# Iter:	25	==================================================>	 mean_squared_error: 27.360% 	 r2_score: 16.63%
#
# Iter:	30	==================================================>	 mean_squared_error: 22.697% 	 r2_score: 30.84%
#
# Iter:	35	==================================================>	 mean_squared_error: 18.905% 	 r2_score: 42.39%
#
# Iter:	40	==================================================>	 mean_squared_error: 15.823% 	 r2_score: 51.78%
#
# Iter:	45	==================================================>	 mean_squared_error: 13.319% 	 r2_score: 59.41%
#
# Iter:	50	==================================================>	 mean_squared_error: 11.285% 	 r2_score: 65.61%
#
# Iter:	55	==================================================>	 mean_squared_error: 9.634% 	 r2_score: 70.64%
#
# Iter:	60	==================================================>	 mean_squared_error: 8.295% 	 r2_score: 74.72%
#
# Iter:	65	==================================================>	 mean_squared_error: 7.208% 	 r2_score: 78.03%
#
# Iter:	70	==================================================>	 mean_squared_error: 6.328% 	 r2_score: 80.72%
#
# Iter:	75	==================================================>	 mean_squared_error: 5.615% 	 r2_score: 82.89%
#
# Iter:	80	==================================================>	 mean_squared_error: 5.038% 	 r2_score: 84.65%
#
# Iter:	85	==================================================>	 mean_squared_error: 4.572% 	 r2_score: 86.07%
#
# Iter:	90	==================================================>	 mean_squared_error: 4.195% 	 r2_score: 87.22%
#
# Iter:	95	==================================================>	 mean_squared_error: 3.891% 	 r2_score: 88.14%
#
# Iter:	100	==================================================>	 mean_squared_error: 3.646% 	 r2_score: 88.89%
#
# Iter:	105	==================================================>	 mean_squared_error: 3.449% 	 r2_score: 89.49%
#
# Iter:	110	==================================================>	 mean_squared_error: 3.291% 	 r2_score: 89.97%
#
# Iter:	115	==================================================>	 mean_squared_error: 3.164% 	 r2_score: 90.36%
#
# Iter:	120	==================================================>	 mean_squared_error: 3.062% 	 r2_score: 90.67%
#
# Iter:	125	==================================================>	 mean_squared_error: 2.981% 	 r2_score: 90.92%
#
# Iter:	130	==================================================>	 mean_squared_error: 2.917% 	 r2_score: 91.11%
#
# Iter:	135	==================================================>	 mean_squared_error: 2.866% 	 r2_score: 91.27%
#
# Iter:	140	==================================================>	 mean_squared_error: 2.825% 	 r2_score: 91.39%
#
# Iter:	145	==================================================>	 mean_squared_error: 2.793% 	 r2_score: 91.49%
#
# Iter:	150	==================================================>	 mean_squared_error: 2.769% 	 r2_score: 91.56%
#
# Iter:	155	==================================================>	 mean_squared_error: 2.749% 	 r2_score: 91.62%
#
# Iter:	160	==================================================>	 mean_squared_error: 2.734% 	 r2_score: 91.67%
#
# Iter:	165	==================================================>	 mean_squared_error: 2.723% 	 r2_score: 91.70%
#
# Iter:	170	==================================================>	 mean_squared_error: 2.714% 	 r2_score: 91.73%
#
# Iter:	175	==================================================>	 mean_squared_error: 2.708% 	 r2_score: 91.75%
#
# Iter:	180	==================================================>	 mean_squared_error: 2.704% 	 r2_score: 91.76%
#
# Iter:	185	==================================================>	 mean_squared_error: 2.700% 	 r2_score: 91.77%
#
# Iter:	190	==================================================>	 mean_squared_error: 2.698% 	 r2_score: 91.78%
#
# Iter:	195	==================================================>	 mean_squared_error: 2.697% 	 r2_score: 91.78%
#
# Iter:	200	==================================================>	 mean_squared_error: 2.696% 	 r2_score: 91.78%
#
# Iter:	205	==================================================>	 mean_squared_error: 2.696% 	 r2_score: 91.79%
#
# Iter:	210	==================================================>	 mean_squared_error: 2.696% 	 r2_score: 91.78%
#
# Iter:	215	==================================================>	 mean_squared_error: 2.696% 	 r2_score: 91.78%
#
# Iter:	220	==================================================>	 mean_squared_error: 2.697% 	 r2_score: 91.78%
#
# Iter:	225	==================================================>	 mean_squared_error: 2.698% 	 r2_score: 91.78%
#
# Iter:	230	==================================================>	 mean_squared_error: 2.698% 	 r2_score: 91.78%
#
# Iter:	235	==================================================>	 mean_squared_error: 2.699% 	 r2_score: 91.78%
#
# Iter:	240	==================================================>	 mean_squared_error: 2.700% 	 r2_score: 91.77%
#
# Iter:	245	==================================================>	 mean_squared_error: 2.701% 	 r2_score: 91.77%
#
# Iter:	250	==================================================>	 mean_squared_error: 2.702% 	 r2_score: 91.77%
#
# Iter:	255	==================================================>	 mean_squared_error: 2.702% 	 r2_score: 91.77%
#
# Iter:	260	==================================================>	 mean_squared_error: 2.703% 	 r2_score: 91.76%
#
# Iter:	265	==================================================>	 mean_squared_error: 2.704% 	 r2_score: 91.76%
#
# Iter:	270	==================================================>	 mean_squared_error: 2.705% 	 r2_score: 91.76%
#
# Iter:	275	==================================================>	 mean_squared_error: 2.705% 	 r2_score: 91.76%
#
# Iter:	280	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.76%
#
# Iter:	285	==================================================>	 mean_squared_error: 2.706% 	 r2_score: 91.75%
#
# Iter:	290	==================================================>	 mean_squared_error: 2.707% 	 r2_score: 91.75%
#
# Iter:	295	==================================================>	 mean_squared_error: 2.707% 	 r2_score: 91.75%
#
# Iter:	300	==================================================>	 mean_squared_error: 2.708% 	 r2_score: 91.75%
#
# Iter:	305	==================================================>	 mean_squared_error: 2.708% 	 r2_score: 91.75%
#
# Iter:	310	==================================================>	 mean_squared_error: 2.708% 	 r2_score: 91.75%
#
# Iter:	315	==================================================>	 mean_squared_error: 2.709% 	 r2_score: 91.75%
#
# Iter:	320	==================================================>	 mean_squared_error: 2.709% 	 r2_score: 91.74%
#
# Iter:	325	==================================================>	 mean_squared_error: 2.709% 	 r2_score: 91.74%
#
# Iter:	330	==================================================>	 mean_squared_error: 2.710% 	 r2_score: 91.74%
#
# Iter:	335	==================================================>	 mean_squared_error: 2.710% 	 r2_score: 91.74%
#
# Iter:	340	==================================================>	 mean_squared_error: 2.710% 	 r2_score: 91.74%
#
# Iter:	345	==================================================>	 mean_squared_error: 2.710% 	 r2_score: 91.74%
#
# Iter:	350	==================================================>	 mean_squared_error: 2.710% 	 r2_score: 91.74%
#
# Iter:	355	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	360	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	365	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	370	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	375	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	380	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	385	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	390	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	395	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	400	==================================================>	 mean_squared_error: 2.711% 	 r2_score: 91.74%
#
# Iter:	405	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	410	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	415	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	420	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	425	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	430	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	435	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	440	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	445	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	450	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	455	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	460	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	465	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	470	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	475	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	480	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	485	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	490	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	495	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%
#
# Iter:	500	==================================================>	 mean_squared_error: 2.712% 	 r2_score: 91.74%

# %%
y_pred=model.predict(x)
r2 = model.metric(y, y_pred)
plt.figure(figsize=(12,8))
plt.scatter(x,y)
plt.plot(x,model.predict(x),lw=4,color="red")
plt.title(f'Functional Regression on Test Data(R2:{r2*100:.2f}%)')
# Out:
# Text(0.5, 1.0, 'Functional Regression on Test Data(R2:91.74%)')
